# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = "https://sb1map.dot.ca.gov/SB1MAP/data/All_Projects.csv"

df = pd.read_csv(url)
print(df.head())
# Out:
#      ProjectID                                       ProjectTitle  \
# 0  '00000PE023         Preliminary Engineering Projects Statewide
# 1  '0020000216              Improve Safety Improvements Statewide
# 2  '0021000337  Planning and Research in Southern California A...
# 3  '0022000337  Planning and Research in Kings County Associat...
# 4  '0022000338               Planning and Research in Kern County
#
#                     Program  \
# 0  Federal Formula Programs
# 1  Federal Formula Programs
# 2  Federal Formula Programs
# 3  Federal Formula Programs
# 4  Federal Formula Programs
#
#                                   ProjectDescription  TotalCost  SB1Funds  \
# 0  Preliminary Engineering Projects Statewide, pa...        NaN       0.0
# 1  Improve Safety Improvements Statewide, part of...        NaN       0.0
# 2  Planning and Research in Southern California A...        NaN       0.0
# 3  Planning and Research in Kings County Associat...        NaN       0.0
# 4  Planning and Research in Kern County, part of ...        NaN       0.0
#
#   ImplementingAgency AssemblyDistricts SenateDistricts CountyNames  ...  \
# 0                NaN               NaN             NaN         NaN  ...
# 1                NaN               NaN             NaN         NaN  ...
# 2                NaN               NaN             NaN         NaN  ...
# 3                NaN               NaN             NaN         NaN  ...
# 4                NaN               NaN             NaN         NaN  ...
#
#   CT_Codes ProjectStatusCodes AgencyID  \
# 0      NaN                NaN      NaN
# 1      NaN                NaN      NaN
# 2      NaN                NaN      NaN
# 3      NaN                NaN      NaN
# 4      NaN                NaN      NaN
#
#                                    IIJAProgram IIJACodes    IIJAFunds IsIIJA  \
# 0  National Highway Performance Program (NHPP)    |NHPP|  247606954.0      Y
# 1    Highway Safety Improvement Program (HSIP)    |HSIP|    1890000.0      Y
# 2                Metropolitan Planning Program     |MPP|   23649647.0      Y
# 3                Metropolitan Planning Program     |MPP|     771058.0      Y
# 4                Metropolitan Planning Program     |MPP|    1800949.0      Y
#
#   IsIIJACode CongressionalDistricts CongressionalCodes
# 0        |Y|                    NaN                NaN
# 1        |Y|                    NaN                NaN
# 2        |Y|                    NaN                NaN
# 3        |Y|                    NaN                NaN
# 4        |Y|                    NaN                NaN
#
# [5 rows x 35 columns]

# %%
import pandas as pd

# Read the city data(data_set)
city_df = pd.read_csv("city_data.csv")

# Check column names of city_df
print(city_df.columns)

# Assuming the correct column name is "County"
merged_df = pd.merge(df, city_df, left_on="CountyNames", right_on="CT_Codes")

print(merged_df)
# Out:
# Index(['ProjectID', 'ProjectTitle', 'Program', 'ProjectDescription',
#        'TotalCost', 'SB1Funds', 'ImplementingAgency', 'AssemblyDistricts',
#        'SenateDistricts', 'CountyNames', 'CityNames', 'CT_Districts',
#        'DateUpdated', 'ProjectStatus', 'ProgramCodes', 'IsOnSHS',
#        'IsOnSHSCode', 'IsSB1', 'IsSB1Code', 'FiscalYear', 'FiscalYearCode',
#        'AssemblyCodes', 'SenateCodes', 'CountyCodes', 'CityCodes', 'CT_Codes',
#        'ProjectStatusCodes', 'AgencyID', 'IIJAProgram', 'IIJACodes',
#        'IIJAFunds', 'IsIIJA', 'IsIIJACode', 'CongressionalDistricts',
#        'CongressionalCodes'],
#       dtype='object')
#       ProjectID_x                              ProjectTitle_x  \
# 0     '00000PE023  Preliminary Engineering Projects Statewide
# 1     '00000PE023  Preliminary Engineering Projects Statewide
# 2     '00000PE023  Preliminary Engineering Projects Statewide
# 3     '00000PE023  Preliminary Engineering Projects Statewide
# 4     '00000PE023  Preliminary Engineering Projects Statewide
# ...           ...                                         ...
# 8699  '1219000083        Safety Improvements in Orange County
# 8700  '1219000083        Safety Improvements in Orange County
# 8701  '1219000083        Safety Improvements in Orange County
# 8702  '1219000083        Safety Improvements in Orange County
# 8703  '1219000083        Safety Improvements in Orange County
#
#                      Program_x  \
# 0     Federal Formula Programs
# 1     Federal Formula Programs
# 2     Federal Formula Programs
# 3     Federal Formula Programs
# 4     Federal Formula Programs
# ...                        ...
# 8699  Federal Formula Programs
# 8700  Federal Formula Programs
# 8701  Federal Formula Programs
# 8702  Federal Formula Programs
# 8703  Federal Formula Programs
#
#                                    ProjectDescription_x  TotalCost_x  \
# 0     Preliminary Engineering Projects Statewide, pa...          NaN
# 1     Preliminary Engineering Projects Statewide, pa...          NaN
# 2     Preliminary Engineering Projects Statewide, pa...          NaN
# 3     Preliminary Engineering Projects Statewide, pa...          NaN
# 4     Preliminary Engineering Projects Statewide, pa...          NaN
# ...                                                 ...          ...
# 8699  Safety Improvements in Orange County, part of ...          NaN
# 8700  Safety Improvements in Orange County, part of ...          NaN
# 8701  Safety Improvements in Orange County, part of ...          NaN
# 8702  Safety Improvements in Orange County, part of ...          NaN
# 8703  Safety Improvements in Orange County, part of ...          NaN
#
#       SB1Funds_x ImplementingAgency_x AssemblyDistricts_x SenateDistricts_x  \
# 0            0.0                  NaN                 NaN               NaN
# 1            0.0                  NaN                 NaN               NaN
# 2            0.0                  NaN                 NaN               NaN
# 3            0.0                  NaN                 NaN               NaN
# 4            0.0                  NaN                 NaN               NaN
# ...          ...                  ...                 ...               ...
# 8699         0.0                  NaN                 NaN               NaN
# 8700         0.0                  NaN                 NaN               NaN
# 8701         0.0                  NaN                 NaN               NaN
# 8702         0.0                  NaN                 NaN               NaN
# 8703         0.0                  NaN                 NaN               NaN
#
#      CountyNames_x  ... CT_Codes_y ProjectStatusCodes_y AgencyID_y  \
# 0              NaN  ...        NaN                  NaN        NaN
# 1              NaN  ...        NaN                  NaN        NaN
# 2              NaN  ...        NaN                  NaN        NaN
# 3              NaN  ...        NaN                  NaN        NaN
# 4              NaN  ...        NaN                  NaN        NaN
# ...            ...  ...        ...                  ...        ...
# 8699           NaN  ...        NaN                  NaN        NaN
# 8700           NaN  ...        NaN                  NaN        NaN
# 8701           NaN  ...        NaN                  NaN        NaN
# 8702           NaN  ...        NaN                  NaN        NaN
# 8703           NaN  ...        NaN                  NaN        NaN
#
#                                           IIJAProgram_y IIJACodes_y  \
# 0           National Highway Performance Program (NHPP)      |NHPP|
# 1             Highway Safety Improvement Program (HSIP)      |HSIP|
# 2                         Metropolitan Planning Program       |MPP|
# 3                         Metropolitan Planning Program       |MPP|
# 4                         Metropolitan Planning Program       |MPP|
# ...                                                 ...         ...
# 8699  Research, Development, and Technology Transfer...       |RDT|
# 8700  Research, Development, and Technology Transfer...       |RDT|
# 8701   Safe and Accessible Transportation Options - SPR   |SATOSPR|
# 8702                        State Planning and Research       |SPR|
# 8703                        State Planning and Research       |SPR|
#
#       IIJAFunds_y IsIIJA_y IsIIJACode_y CongressionalDistricts_y  \
# 0     247606954.0        Y          |Y|                      NaN
# 1       1890000.0        Y          |Y|                      NaN
# 2      23649647.0        Y          |Y|                      NaN
# 3        771058.0        Y          |Y|                      NaN
# 4       1800949.0        Y          |Y|                      NaN
# ...           ...      ...          ...                      ...
# 8699   17075657.0        Y          |Y|                      NaN
# 8700   16438052.0        Y          |Y|                      NaN
# 8701    2275891.0        Y          |Y|                      NaN
# 8702   62316970.0        Y          |Y|                      NaN
# 8703   62414884.0        Y          |Y|                      NaN
#
#      CongressionalCodes_y
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
# ...                   ...
# 8699                  NaN
# 8700                  NaN
# 8701                  NaN
# 8702                  NaN
# 8703                  NaN
#
# [8704 rows x 70 columns]

# %%
df = df[['ProjectID', 'ProjectTitle', 'ProjectDescription', 'TotalCost', 'CountyNames', 'CT_Codes', 'ProjectStatusCodes']]
print(df.head())
# Out:
#      ProjectID                                       ProjectTitle  \
# 0  '00000PE023         Preliminary Engineering Projects Statewide
# 1  '0020000216              Improve Safety Improvements Statewide
# 2  '0021000337  Planning and Research in Southern California A...
# 3  '0022000337  Planning and Research in Kings County Associat...
# 4  '0022000338               Planning and Research in Kern County
#
#                                   ProjectDescription  TotalCost CountyNames  \
# 0  Preliminary Engineering Projects Statewide, pa...        NaN         NaN
# 1  Improve Safety Improvements Statewide, part of...        NaN         NaN
# 2  Planning and Research in Southern California A...        NaN         NaN
# 3  Planning and Research in Kings County Associat...        NaN         NaN
# 4  Planning and Research in Kern County, part of ...        NaN         NaN
#
#   CT_Codes ProjectStatusCodes
# 0      NaN                NaN
# 1      NaN                NaN
# 2      NaN                NaN
# 3      NaN                NaN
# 4      NaN                NaN

# %%
df_filtered = df[df['CountyNames'].isin(['Bakersfield', 'Richmond'])]

print(df_filtered)
# Out:
# Empty DataFrame
# Columns: [ProjectID, ProjectTitle, ProjectDescription, TotalCost, CountyNames, CT_Codes, ProjectStatusCodes]
# Index: []

# %%
city_url = "https://sb1map.dot.ca.gov/SB1MAP/data/Cities.csv"
city_df = pd.read_csv(city_url)

city_df.head()
# Out:
#            City CityCode          County CountyCode  Lon_Centroid  \
# 0      Adelanto     ADEL  San Bernardino        SBD   -117.441234
# 1  Agoura Hills     AGRH     Los Angeles         LA   -118.760110
# 2       Alameda      ALA         Alameda        ALA   -122.278289
# 3        Albany      ALB         Alameda        ALA   -122.300416
# 4      Alhambra      ALH     Los Angeles         LA   -118.135526
#
#    Lat_Centroid
# 0     34.586868
# 1     34.153635
# 2     37.779933
# 3     37.889852
# 4     34.083981

# %%
merged_df = pd.merge(df, city_df, left_on="CountyNames", right_on="County")

print(merged_df)
# Out:
#                       ProjectID                                ProjectTitle  \
# 0                   '0100000012  East Side Potter Valley Road Recon Phase I
# 1                   '0100000012  East Side Potter Valley Road Recon Phase I
# 2                   '0100000012  East Side Potter Valley Road Recon Phase I
# 3                   '0100000012  East Side Potter Valley Road Recon Phase I
# 4                   '0100000059       Waterfront Drive Connection Phase II.
# ...                         ...                                         ...
# 349495  'TEMP-SGR-2023-6071-054      HVAC Replacement at Santa Ana Bus Base
# 349496  'TEMP-SGR-2023-6071-054      HVAC Replacement at Santa Ana Bus Base
# 349497  'TEMP-SGR-2023-6071-054      HVAC Replacement at Santa Ana Bus Base
# 349498  'TEMP-SGR-2023-6071-054      HVAC Replacement at Santa Ana Bus Base
# 349499  'TEMP-SGR-2023-6071-054      HVAC Replacement at Santa Ana Bus Base
#
#                                        ProjectDescription  TotalCost  \
# 0       In Potter Valley, East Side Potter Valley Road...  8290000.0
# 1       In Potter Valley, East Side Potter Valley Road...  8290000.0
# 2       In Potter Valley, East Side Potter Valley Road...  8290000.0
# 3       In Potter Valley, East Side Potter Valley Road...  8290000.0
# 4       In Eureka, along Waterfront Drive between G St...  4157000.0
# ...                                                   ...        ...
# 349495  Replacement of HVAC, heating, and ventilating ...  1150000.0
# 349496  Replacement of HVAC, heating, and ventilating ...  1150000.0
# 349497  Replacement of HVAC, heating, and ventilating ...  1150000.0
# 349498  Replacement of HVAC, heating, and ventilating ...  1150000.0
# 349499  Replacement of HVAC, heating, and ventilating ...  1150000.0
#
#        CountyNames CT_Codes ProjectStatusCodes         City CityCode  \
# 0        Mendocino     |01|       |InProgress|   Fort Bragg      FBG
# 1        Mendocino     |01|       |InProgress|  Point Arena      PTA
# 2        Mendocino     |01|       |InProgress|        Ukiah      UKI
# 3        Mendocino     |01|       |InProgress|      Willits     WLTS
# 4         Humboldt     |01|       |InProgress|       Arcata      ARC
# ...            ...      ...                ...          ...      ...
# 349495      Orange     |12|          |Planned|      Stanton      STT
# 349496      Orange     |12|          |Planned|       Tustin      TUS
# 349497      Orange     |12|          |Planned|   Villa Park     VLPK
# 349498      Orange     |12|          |Planned|  Westminster      WTM
# 349499      Orange     |12|          |Planned|  Yorba Linda     YBLN
#
#            County CountyCode  Lon_Centroid  Lat_Centroid
# 0       Mendocino        MEN   -123.802924     39.442854
# 1       Mendocino        MEN   -123.695571     38.912279
# 2       Mendocino        MEN   -123.210812     39.146936
# 3       Mendocino        MEN   -123.356708     39.409273
# 4        Humboldt        HUM   -124.076975     40.872226
# ...           ...        ...           ...           ...
# 349495     Orange        ORA   -117.993482     33.800199
# 349496     Orange        ORA   -117.810750     33.730830
# 349497     Orange        ORA   -117.810191     33.818102
# 349498     Orange        ORA   -118.018447     33.762430
# 349499     Orange        ORA   -117.771990     33.889222
#
# [349500 rows x 13 columns]

# %%
# user_input = input("Enter a city name: ")
city_name = ['Richmond', 'bakersfield', 'wasco', 'eureka', 'Arcata', 'Mckinleyville', 'sanrafael', 'novato', 'Millivalley', 'Riverside', 'moreno', 'Corona', 'sacramento', 'citrus heights', 'elk grove', 'San Bernardino', 'Fontana', 'Ontario', 'Chula Vista', 'OceanSide', 'san', 'paso', 'atascadero', 'sanmateo', 'daily', 'lompoc', 'santa maria', 'santa clara', 'vacaville', 'vallejo', 'fairfield', 'Rohnert', 'santa', 'petaluma', 'thousand', 'simivalley', 'shoreline']

filtered_df = pd.DataFrame()
for name in city_name:

  for index, row in merged_df.iterrows():
    if row["City"] == name:
      # filtered_df = filtered_df.append(row)
      filtered_df = pd.concat([filtered_df, pd.DataFrame(row).T], ignore_index=True)


print(filtered_df)
# Out:
#                     ProjectID  \
# 0                 '0000202305
# 1                 '0412000064
# 2                 '0412000074
# 3                 '0412000159
# 4                 '0413000055
# ...                       ...
# 4519       'STA-20220301-0003
# 4520       'STA-20220301-0004
# 4521       'STA-20230301-0003
# 4522       'STA-20230301-0004
# 4523  'TEMP-SGR-2022-6042-048
#
#                                            ProjectTitle  \
# 0                           Richmond MOVES Microtransit
# 1     Richmond San Rafael Bridge - Upgrade Electrica...
# 2     Richmond San Rafael Structural Steel Paint Pro...
# 3                               Pavement Rehabilitation
# 4                           Bridge Major Rehabilitation
# ...                                                 ...
# 4519  San Diego Association of Governments Fiscal Ye...
# 4520  San Diego Metropolitan Transit System Fiscal Y...
# 4521  San Diego Association of Governments Fiscal Ye...
# 4522  San Diego Metropolitan Transit System Fiscal Y...
# 4523                  Transit Repair and Rehabilitation
#
#                                      ProjectDescription    TotalCost  \
# 0     The Project expands existing microtransit serv...    6235000.0
# 1     Richmond - San Rafael Bridge: Electrical Subst...   19015000.0
# 2     In Contra Costa and Marin Counties, within the...   85030000.0
# 3     A $13.66 million dollar project in Contra Cost...  13660737.65
# 4     A $4.01 million dollar project in Contra Costa...   4006015.29
# ...                                                 ...          ...
# 4519  San Diego Association of Governments Fiscal Ye...   10749743.0
# 4520  San Diego Metropolitan Transit System Fiscal Y...   30023001.0
# 4521  San Diego Association of Governments Fiscal Ye...    1819764.0
# 4522  San Diego Metropolitan Transit System Fiscal Y...    5084971.0
# 4523  Expenses to maintain existing infrastructure a...    3597522.0
#
#        CountyNames CT_Codes ProjectStatusCodes         City CityCode  \
# 0     Contra Costa     |04|          |Planned|     Richmond      RCH
# 1     Contra Costa     |04|          |Planned|     Richmond      RCH
# 2     Contra Costa     |04|       |InProgress|     Richmond      RCH
# 3     Contra Costa     |04|        |Completed|     Richmond      RCH
# 4     Contra Costa     |04|        |Completed|     Richmond      RCH
# ...            ...      ...                ...          ...      ...
# 4519     San Diego     |11|        |Completed|  Chula Vista      CHV
# 4520     San Diego     |11|        |Completed|  Chula Vista      CHV
# 4521     San Diego     |11|       |InProgress|  Chula Vista      CHV
# 4522     San Diego     |11|       |InProgress|  Chula Vista      CHV
# 4523     San Diego     |11|       |InProgress|  Chula Vista      CHV
#
#             County CountyCode Lon_Centroid Lat_Centroid
# 0     Contra Costa         CC  -122.383056    37.938759
# 1     Contra Costa         CC  -122.383056    37.938759
# 2     Contra Costa         CC  -122.383056    37.938759
# 3     Contra Costa         CC  -122.383056    37.938759
# 4     Contra Costa         CC  -122.383056    37.938759
# ...            ...        ...          ...          ...
# 4519     San Diego         SD  -116.975272    32.628803
# 4520     San Diego         SD  -116.975272    32.628803
# 4521     San Diego         SD  -116.975272    32.628803
# 4522     San Diego         SD  -116.975272    32.628803
# 4523     San Diego         SD  -116.975272    32.628803
#
# [4524 rows x 13 columns]

# %%
filtered_df.to_csv('scraped_data.csv')
